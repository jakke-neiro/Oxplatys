# %% [markdown]
# # 8-4-Enrichment-Analysis-R
# Jakke Neiro$^1$
#
# 1. Aboobaker laboratory, Department of Zoology, University of Oxford

# %% [markdown]
# FPR_unbound_coe, FPR_bound_coe, TPR_unbound_coe, TPR_bound_coe

# %%
coe = read.csv("/drives/raid/AboobakerLab/jakke/TF_RNAi_RNAseq/Cowles2014/ROC.csv")

# %%
coe_roc = data.frame("FPR" = c(coe$coe[1], coe$coe[2]), "TPR" = c(coe$coe[3], coe$coe[4]), "Color" = c("unbound", "bound"))

# %%
foxd = read.csv("/drives/raid/AboobakerLab/jakke/TF_RNAi_RNAseq/Vogg2014/ROC.csv")

# %%
foxd_roc = data.frame("FPR" = c(foxd$fox[1], foxd$fox[2]), "TPR" = c(foxd$fox[3], foxd$fox[4]), "Color" = c("unbound", "bound"))

# %%
roc_summary = rbind(coe_roc, foxd_roc)

# %% [markdown]
# ## ROC Curve

# %%
library(ggplot2)

# %%
library(ggplot2)
options(repr.plot.width = 10, repr.plot.height = 8)
p = ggplot(roc_summary, aes(x=FPR, y=TPR, col=Color)) + geom_point(size=2)
p = p + theme_minimal()
p = p + theme(plot.title = element_text(hjust = 0.5), title=element_text(size=20), axis.text.y=element_text(size=25), axis.text.x=element_text(size=25), axis.title=element_text(size=25), legend.title=element_text(size=25), legend.text=element_text(size=25))
p = p + geom_abline(intercept = 0, slope = 1, linetype="dashed")+xlim(0,1)+ylim(0,1)
p = p + xlab("\nFalse positive rate (FPR)") + ylab("True positive rate (TPR)\n")
#p = p + stat_smooth(method='lm', formula = y~poly(x,2))
p
# Out:
# plot without title

# %% [markdown]
# # Cowles 2014

# %%
cowles2014 <- matrix(c(33, 22, 4, 2), ncol = 2)

# %%
cowles2014
# Out:
#      [,1] [,2]
# [1,] 33   4
# [2,] 22   2

# %%
fisher.test(cowles2014)
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  cowles2014
# p-value = 1
# alternative hypothesis: true odds ratio is not equal to 1
# 95 percent confidence interval:
#  0.06307762 5.78827945
# sample estimates:
# odds ratio
#  0.7534468

# %%
chisq.test(cowles2014)
# Out:
# Warning message in chisq.test(cowles2014):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  cowles2014
# X-squared = 5.5093e-31, df = 1, p-value = 1

# %%
Voggann = read.csv("/drives/raid/AboobakerLab/jakke/TF_RNAi_RNAseq/Cowles2014/res_Cowles2014_annotated.csv")

# %%
library(ggplot2)
options(repr.plot.width = 10, repr.plot.height = 7)
p = ggplot(Voggann, aes(x=log2FoldChange, y=padj, col=Motif)) + geom_point(size=1.2)
#p = p + geom_ribbon(aes(ymin=lower, ymax=upper), linetype=1, alpha=0.2)
#p = p + theme_minimal() + scale_colour_brewer(name="Enrichment group", palette="Spectral")
#p = p + theme(plot.title = element_text(hjust = 0.5), title=element_text(size=20), axis.text.y=element_text(size=20), axis.text.x=element_text(size=25), axis.title=element_text(size=25), legend.title=element_text(size=25), legend.text=element_text(size=25))
#p = p + xlab("\nTSS (+/- bp)") + ylab("H3K27ac log2 fold-change X1 cells\n")
p
# Out:
# Warning message:
# “Removed 11949 rows containing missing values (geom_point).”
# plot without title

# %%
library(ggplot2)
options(repr.plot.width = 10, repr.plot.height = 7)
p = ggplot(Voggann, aes(x=padj, y=X1prop, col=Motif)) + geom_point(size=1.2)
#p = p + geom_ribbon(aes(ymin=lower, ymax=upper), linetype=1, alpha=0.2)
#p = p + theme_minimal() + scale_colour_brewer(name="Enrichment group", palette="Spectral")
#p = p + theme(plot.title = element_text(hjust = 0.5), title=element_text(size=20), axis.text.y=element_text(size=20), axis.text.x=element_text(size=25), axis.title=element_text(size=25), legend.title=element_text(size=25), legend.text=element_text(size=25))
#p = p + xlab("\nTSS (+/- bp)") + ylab("H3K27ac log2 fold-change X1 cells\n")
p
# Out:
# Warning message:
# “Removed 11951 rows containing missing values (geom_point).”
# plot without title

# %%
#library(ggpubr)
options(repr.plot.width = 6, repr.plot.height = 6)
#my_comparisons = list( c("a", "2"), c("3", "4"), c("1", "3"),c("1", "4"))
p = ggplot(Voggann, aes(x=Motif, y=padj, fill=log2FoldChange)) +geom_jitter(size=0.3, alpha=0.3) + geom_boxplot(alpha=0.5)
p = p + theme_minimal()
p = p + theme(plot.title = element_text(hjust = 0.5), title=element_text(size=30), axis.text.y=element_text(size=30), axis.text.x=element_text(size=25), axis.title=element_text(size=35), legend.position="none", legend.title=element_text(), legend.text=element_text(size=25))
#p = p + scale_fill_manual(name=" ", values=c("navyblue", "orange"))
#p = p + scale_x_discrete(labels=c("SMESG", "Isoforms", "New\ncoding", "New\nnon-coding"))
#p = p + xlab("") + ylab("Transcript length (bp)\n")
#p = p + scale_y_continuous(trans="log10")+stat_compare_means(label.y = 6.2, label.x=2.2, size=10)+stat_compare_means(comparisons = my_comparisons, size=8)
p
# Out:
# Warning message:
# “Removed 11949 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 11949 rows containing missing values (geom_point).”
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
 p = ggplot(Voggann, aes(x=padj, fill=Motif)) +geom_density(alpha=0.5)
p = p + theme_minimal()
p = p + geom_vline(xintercept=0.05)
p
# Out:
# Warning message:
# “Removed 11949 rows containing non-finite values (stat_density).”
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
p = ggplot(Voggann, aes(x=X1prop, fill=Motif)) +geom_density(alpha=0.5)
p = p + theme_minimal()
p = p + geom_vline(xintercept=0.05)
p
# Out:
# Warning message:
# “Removed 432 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# # Vogg 2014

# %%
vogg2014 <- matrix(c(79, 3, 7, 1), ncol = 2)

# %%
fisher.test(vogg2014)
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  vogg2014
# p-value = 0.3155
# alternative hypothesis: true odds ratio is not equal to 1
# 95 percent confidence interval:
#   0.06278231 53.56122511
# sample estimates:
# odds ratio
#   3.673914

# %%
chisq.test(vogg2014)
# Out:
# Warning message in chisq.test(vogg2014):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  vogg2014
# X-squared = 0.067401, df = 1, p-value = 0.7952

# %%
all = cbind(cowles2014, vogg2014)

# %%
all
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 33   4    79   7
# [2,] 22   2     3   1

# %%
fisher.test(all)
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  all
# p-value = 2.85e-07
# alternative hypothesis: two.sided

# %%
chisq.test(all)
# Out:
# Warning message in chisq.test(all):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  all
# X-squared = 29.854, df = 3, p-value = 1.481e-06
