# %% [markdown]
# # 6-2-Enhancer-analysis
# Jakke Neiro$^1$
# 1. Aboobaker laboratory, Department of Zoology, University of Oxford

# %% [markdown]
# ## Contents of notebook
# 1. Introduction
# 2. Enhancer analysis: all genes

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# # 2. Enhancer analysis: all genes

# %%
import pandas as pd
FACS_prop = pd.read_csv("/hydra/FACS/FACS_prop.csv")
enhancer_annotation_FACS = pd.read_csv("/hydra/FACS/enhancer_annotation_FACSRNAi_annotated_deseq2_oct21.csv")
enhancer_annotation_FACS = enhancer_annotation_FACS[(~enhancer_annotation_FACS["annotation"].str.contains("Exon"))]

# %%
import pandas as pd
data = pd.read_csv("/drives/raid/AboobakerLab/jakke/TF_data/edges_grn_neospec_bound2021.csv")
data.to_excel("/drives/raid/AboobakerLab/jakke/TF_data/edges_grn_neospec_bound2021.xlsx")

# %%
human = pd.read_csv("/hydra/sexual_genome_annotation_files/blast_annotation/human_gene_blast.tab", sep="\t")

# %%
enhancer_annotation_FACS["GeneDescription"] = "-"
enhancer_annotation_FACS["GeneName"] = "-"
for i in range(len(enhancer_annotation_FACS)):
    gene_id = enhancer_annotation_FACS.iloc[i,13]
    table = human[human.iloc[:,16] == gene_id]
    if len(table) > 0:
        enhancer_annotation_FACS["GeneDescription"].iloc[i] = table.iloc[0,12]
        enhancer_annotation_FACS["GeneName"].iloc[i] = table.iloc[0,13]
    if i%1000 == 1:
        print(i)
enhancer_annotation_FACS.to_csv("/hydra/FACS/enhancer_annotation_FACSRNAi_annotated_deseq2_namesoct21.csv", index=False)
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 1
# 1001
# 2001
# 3001
# 4001

# %%
import pandas as pd
X1_table = pd.read_csv("/hydra/atac_sexual_final/footprinting/BINDetect_X1/X1_table.csv")
X1_table_bound = X1_table[X1_table["X1_bound"] == 1]

# %%
import pandas as pd
enhancer_tfs_mbd34enriched = pd.read_csv("/hydra/FACS/enhancer_annotation_FACSRNAi_annotated_deseq2_namesoct21.csv")
enhancer_final = enhancer_tfs_mbd34enriched
enhancer_final["Bound motifs"] = "-"
enhancer_final["Bound motif names"] = "-"
enhancer_final["Bound counts"] = 0
enhancer_final["Unbound motifs"] = "-"
enhancer_final["Unbound motif names"] = "-"
enhancer_final["Unbound counts"] = 0
for i in range(len(enhancer_final)):
    chrom = enhancer_final["seqnames"].iloc[i]
    start = enhancer_final["start"].iloc[i]
    motif_table = X1_table_bound[(abs(X1_table_bound["TFBS_start"] - start) < 1000)&(X1_table_bound["TFBS_chr"] == chrom)]
    gene_strs = []
    name_strs = []
    if len(motif_table) > 0:
        gene_str = motif_table["GeneID"].iloc[0]
        gene_strs.append(motif_table["GeneID"].iloc[0])
        name_str = motif_table["TF name"].iloc[0]
        name_strs.append(motif_table["TF name"].iloc[0])
        enhancer_final["Bound counts"].iloc[i] = enhancer_final["Bound counts"].iloc[i]+1
        for j in range(1,len(motif_table)):
            if motif_table["GeneID"].iloc[j] not in gene_strs:
                gene_str = gene_str + ":" + motif_table["GeneID"].iloc[j]
                gene_strs.append(motif_table["GeneID"].iloc[j])
                enhancer_final["Bound counts"].iloc[i] = enhancer_final["Bound counts"].iloc[i]+1
            if motif_table["TF name"].iloc[j] not in name_strs:
                name_str = name_str + ":" + motif_table["TF name"].iloc[j]
                name_strs.append(motif_table["TF name"].iloc[j])
        enhancer_final["Bound motifs"].iloc[i] = gene_str
        enhancer_final["Bound motif names"].iloc[i] = name_str
    unbound_motif_table = X1_table[(abs(X1_table["TFBS_start"] - start) < 1000)&(X1_table["TFBS_chr"] == chrom)]
    if len(unbound_motif_table) > 0:
        gene_str = unbound_motif_table["GeneID"].iloc[0]
        gene_strs.append(unbound_motif_table["GeneID"].iloc[0])
        name_str = unbound_motif_table["TF name"].iloc[0]
        name_strs.append(unbound_motif_table["TF name"].iloc[0])
        enhancer_final["Unbound counts"].iloc[i] = enhancer_final["Unbound counts"].iloc[i]+1
        for j in range(1,len(unbound_motif_table)):
            if unbound_motif_table["GeneID"].iloc[j] not in gene_strs:
                gene_str = gene_str + ":" + unbound_motif_table["GeneID"].iloc[j]
                gene_strs.append(unbound_motif_table["GeneID"].iloc[j])
                enhancer_final["Unbound counts"].iloc[i] = enhancer_final["Unbound counts"].iloc[i]+1
            if unbound_motif_table["TF name"].iloc[j] not in name_strs:
                name_str = name_str + ":" + unbound_motif_table["TF name"].iloc[j]
                name_strs.append(unbound_motif_table["TF name"].iloc[j])
        enhancer_final["Unbound motifs"].iloc[i] = gene_str
        enhancer_final["Unbound motif names"].iloc[i] = name_str
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
enhancer_final.to_excel("/hydra/enhancer_regions/enhancer_all_oct2021.xlsx")

# %%
import numpy as np
counts = []
motif_counts = []
motif_counts_unbound = []
gene_ids = pd.Categorical(enhancer_final["geneId"]).categories
gene_names = []
gene_desc = []
logFCgene = []
logFCenhancer = []
for i in range(len(gene_ids)):
    table = enhancer_final[enhancer_final["geneId"] == gene_ids[i]]
    counts.append(len(table))
    gene_names.append(table["GeneDescription"].iloc[0])
    gene_desc.append(table["GeneName"].iloc[0])
    logFCgene.append(table["K4me1RNAlogFC"].iloc[0])
    logFCenhancer.append(np.mean(table["K4me1RNAi"]))
    motif_counts.append(np.sum(table["Bound counts"]))
    motif_counts_unbound.append(np.sum(table["Unbound counts"]))
counts_table = pd.DataFrame({"Gene ID": gene_ids, "Name":gene_names, "Description": gene_desc, "logFC gene": logFCgene, "abs(logFC)": np.abs(logFCgene), "logFC enhancer":logFCenhancer, "Counts":counts, "Motif bound count":motif_counts, "Motif unbound count":motif_counts_unbound}).sort_values(by="Motif bound count", ascending=False)
#pd.DataFrame({"Name":gene_names, "logFC gene":logFCgene, "abs(logFC)": np.abs(logFCgene), "logFC enhancer":logFCenhancer, "Counts":counts, "Motif bound count":motif_counts, "Motif unbound count":motif_counts_unbound}).sort_values(by="abs(logFC)", ascending=False)

# %%
counts_table.to_excel("/hydra/enhancer_regions/enhancer_all_counts_oct2021.xlsx")

# %% [markdown]
# # 3. Gene regulatory networks

# %%
import pandas as pd
enhancer_final = pd.read_excel("/hydra/enhancer_regions/enhancer_table_aug2021.xlsx").iloc[:,1:]

# %%
import pandas as pd
enhancer_final = pd.read_excel("/drives/raid/AboobakerLab/jakke/enhancer_regions/enhancer_table_oct2021.xlsx").iloc[:,1:]

# %%
FACS_prop = pd.read_csv("/drives/raid/AboobakerLab/jakke/FACS/FACS_prop.csv")

# %%
def table_to_igraph_links(enhancer_final, a):
    node_1 = []
    node_2 = []
    node_name = []
    for i in range(len(enhancer_final)):
        n2_s = enhancer_final[a].iloc[i].split(":")
        for j in range(len(n2_s)):
            if n2_s[j] != "-":
                node_2.append(n2_s[j])
                node_1.append(enhancer_final["Neiro"].iloc[i])
    table = pd.DataFrame({"Node1": node_2, "Node2": node_1}).drop_duplicates()
    return table

# %%
def table_to_igraph_nodes(enhancer_final, a, b):
    nodes = []
    node_name = []
    x1 = []
    x1prop = []
    for i in range(len(enhancer_final)):
        n2_s = enhancer_final[a].iloc[i].split(":")
        names_s = enhancer_final[b].iloc[i].split(":")
        for j in range(len(n2_s)):
            if n2_s[j] != "-":
                if n2_s[j] not in nodes:
                    nodes.append(n2_s[j])
                    node_name.append(names_s[j])
                    x1facs = FACS_prop[FACS_prop["gene"] == n2_s[j]]
                    if len(x1facs) > 0:
                        x1.append(x1facs["X1"].iloc[0])
                        x1prop.append(x1facs["X1.prop"].iloc[0])
                    else:
                        x1.append(0)
                        x1prop.append(0)
                if enhancer_final["Neiro"].iloc[i] not in nodes:
                    nodes.append(enhancer_final["Neiro"].iloc[i])
                    node_name.append(enhancer_final["Symbol"].iloc[i])
                    x1.append(enhancer_final["X1"].iloc[i])
                    x1prop.append(enhancer_final["X1 percent"].iloc[i])
    table = pd.DataFrame({"Nodes": nodes, "Name": node_name, "X1": x1, "X1.prop": x1prop})
    return table

# %%
nodes = table_to_igraph_nodes(enhancer_final, "Bound motifs", "Bound motif names")
len(nodes)

# %%
links = table_to_igraph_links(enhancer_final, "Bound motifs")[(table_to_igraph_links(enhancer_final, "Bound motifs")["Node1"].isin(nodes["Nodes"]))&(table_to_igraph_links(enhancer_final, "Bound motifs")["Node2"].isin(nodes["Nodes"]))]

# %%
links.to_csv("/hydra/TF_data/edges_grn_tf_bound2021.csv", index=False)
nodes.to_csv("/hydra/TF_data/vertices_grn_tf_bound2021.csv", index=False)

# %% [markdown]
# edges_grn_tf_bound2021.csv and vertices_grn_tf_bound2021.csv are used in 6-4-Networks-R

# %% [markdown]
# # 4. Distance to promoters per transcription factor type

# %%
import pandas as pd
enhancer_final = pd.read_excel("/drives/raid/AboobakerLab/jakke/enhancer_regions/enhancer_all_oct2021.xlsx").iloc[:,1:]

# %%
import pandas as pd
X1_table = pd.read_csv("/drives/raid/AboobakerLab/jakke/atac_sexual_final/footprinting/BINDetect_X1/X1_table.csv")
X1_table_bound = X1_table[X1_table["X1_bound"] == 1]

# %%
X1_table_bound.iloc[:, 0:3].to_csv("/drives/raid/AboobakerLab/jakke/atac_sexual_final/footprinting//BINDetect_X1/X1_bound_bedfile.bed", sep="\t", index=None, header=None)

# %%
import pandas as pd
X1_bound = pd.read_csv("/drives/raid/AboobakerLab/jakke/atac_sexual_final/footprinting/BINDetect_X1/X1_bound_distance.csv")

# %%
bound_concat = pd.concat([X1_bound.reset_index(drop="TRUE"), X1_table_bound.reset_index(drop="TRUE")], axis=1)

# %%
bound_concat = bound_concat[bound_concat["TF name"] != "a"]

# %%
bound_concat.to_csv("/drives/raid/AboobakerLab/jakke/atac_sexual_final/footprinting/BINDetect_X1/X1_bound_distance_names.csv")

# %%
import numpy as np
promoters = []
distal = []
#totals
motif_names = list(pd.Categorical(bound_concat["TF name"]).categories)
for i in motif_names:
    subset = bound_concat[bound_concat["TF name"] == i]
    promoters.append(len(subset[subset["distanceToTSS"] < 500])/len(subset))
    distal.append(len(subset[subset["distanceToTSS"] > 10000])/len(subset))

# %%
pd.DataFrame({"name": motif_names, "fraction": promoters, "distal": distal}).to_csv("/drives/raid/AboobakerLab/jakke/atac_sexual_final/footprinting/BINDetect_X1/X1_bound_promoterfraction.csv")
