# %% [markdown]
# # 2. ATAC signal at ChIP-seq peaks

# %% [markdown]
# ## 2.1 X1

# %% [markdown]
# ### ATAC signal

# %%
# %%bash
# cd /hydra/atac_sexual_final/x1/
# echo "#!/bin/bash" > bamCoverage_atacmatrix.sh
# echo "computeMatrix reference-point -S x1coverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab" >> bamCoverage_atacmatrix.sh
# chmod +x bamCoverage_atacmatrix.sh
# less bamCoverage_atacmatrix.sh
# Out:
# #!/bin/bash
# computeMatrix reference-point -S x1coverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab

# %%
#%%bash
#cd /hydra/atac_sexual_final/x1/
#nohup ./bamCoverage_atacmatrix.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final/x1/
# plotHeatmap -m atacaroundchip_july21 -o atacaroundchip_july21.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " "

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x1/atacaroundchip_july21.png')

# %%
# %%bash
# cd /hydra/enhancer_regions
# wc -l random_peaks.bed
# Out:
# 10000 random_peaks.bed

# %%
# %%bash
# cd /hydra/atac_sexual_final/x1/
# echo "#!/bin/bash" > bamCoverage_randommatrix.sh
# echo "computeMatrix reference-point -S x1coverage_mean_april2021.bw -R /hydra/enhancer_regions/random_peaks.bed -a 1000 -b 1000 -o atacaroundrandom_july21 --outFileNameMatrix atacaroundrandom_july21.tab" >> bamCoverage_randommatrix.sh
# chmod +x bamCoverage_randommatrix.sh
# less bamCoverage_randommatrix.sh

# %%
#%%bash
#cd /hydra/atac_sexual_final/x1/
#nohup ./bamCoverage_randommatrix.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final/x1/
# plotHeatmap -m atacaroundrandom_july21 -o atacaroundrandom_july21.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " "
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/deeptools/heatmapper.py:1219: RuntimeWarning:
#
# Mean of empty slice

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x1/atacaroundrandom_july21.png')

# %% [markdown]
# ### Footprinting score

# %%
# %%bash
# cd /hydra/atac_sexual_final/x1/
# echo "#!/bin/bash" > bamCoverage_footprintmatrix.sh
# echo "computeMatrix reference-point -S x1marked_footprints_regions.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o footprintaroundchip_july21 --outFileNameMatrix footprintaroundchip_july21.tab" >> bamCoverage_footprintmatrix.sh
# chmod +x bamCoverage_footprintmatrix.sh
# less bamCoverage_footprintmatrix.sh

# %% [markdown]
# ## 2.2 X2

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# echo "#!/bin/bash" > bamCoverage_atacmatrix.sh
# echo "computeMatrix reference-point -S x2coverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab" >> bamCoverage_atacmatrix.sh
# chmod +x bamCoverage_atacmatrix.sh
# less bamCoverage_atacmatrix.sh
# Out:
# #!/bin/bash
# computeMatrix reference-point -S x2coverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab

# %%
#%%bash
#cd /hydra/atac_sexual_final/x2/
#nohup ./bamCoverage_atacmatrix.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# plotHeatmap -m atacaroundchip_july21 -o atacaroundchip_july21.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " "

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# plotHeatmap -m atacaroundchip_july21 -o atacaroundchip_july21_2.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " " -min 0 -max 10 --yMin 0 --yMax 8

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x2/atacaroundchip_july21.png')

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x2/atacaroundchip_july21_2.png')

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# echo "#!/bin/bash" > bamCoverage_randommatrix.sh
# echo "computeMatrix reference-point -S x2coverage_mean_april2021.bw -R /hydra/enhancer_regions/random_peaks.bed -a 1000 -b 1000 -o atacaroundrandom_july21 --outFileNameMatrix atacaroundrandom_july21.tab" >> bamCoverage_randommatrix.sh
# chmod +x bamCoverage_randommatrix.sh
# less bamCoverage_randommatrix.sh
# Out:
# #!/bin/bash
# computeMatrix reference-point -S x2coverage_mean_april2021.bw -R /hydra/enhancer_regions/random_peaks.bed -a 1000 -b 1000 -o atacaroundrandom_july21 --outFileNameMatrix atacaroundrandom_july21.tab

# %%
#%%bash
#cd /hydra/atac_sexual_final/x2/
#nohup ./bamCoverage_randommatrix.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# plotHeatmap -m atacaroundrandom_july21 -o atacaroundrandom_july21.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " "
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/deeptools/heatmapper.py:1219: RuntimeWarning:
#
# Mean of empty slice

# %%
# %%bash
# cd /hydra/atac_sexual_final/x2/
# plotHeatmap -m atacaroundrandom_july21 -o atacaroundrandom_july21_2.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " " -min 0 -max 10 --yMin 0 --yMax 10
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/deeptools/heatmapper.py:1219: RuntimeWarning:
#
# Mean of empty slice

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x2/atacaroundrandom_july21.png')

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/x2/atacaroundrandom_july21_2.png')

# %% [markdown]
# ## 2.3 Xins

# %%
# %%bash
# cd /hydra/atac_sexual_final/xins/
# echo "#!/bin/bash" > bamCoverage_atacmatrix.sh
# echo "computeMatrix reference-point -S xinscoverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab" >> bamCoverage_atacmatrix.sh
# chmod +x bamCoverage_atacmatrix.sh
# less bamCoverage_atacmatrix.sh
# Out:
# #!/bin/bash
# computeMatrix reference-point -S xinscoverage_mean_april2021.bw -R /hydra/enhancer_regions/chip_summits_july21.bed -a 1000 -b 1000 -o atacaroundchip_july21 --outFileNameMatrix atacaroundchip_july21.tab

# %%
#%%bash
#cd /hydra/atac_sexual_final/xins/
#nohup ./bamCoverage_atacmatrix.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final/xins/
# plotHeatmap -m atacaroundchip_july21 -o atacaroundchip_july21.png --samplesLabel "ATAC" --boxAroundHeatmaps no --missingDataColor 1 --xAxisLabel "Distance (bp)" --plotType se --whatToShow "plot and heatmap" --heatmapHeight 17.5 --heatmapWidth 2.5 -y "log2 fold change" --refPointLabel "Peak" -z " "

# %%
from IPython.display import Image
Image(filename='/hydra/atac_sexual_final/xins/atacaroundchip_july21.png')

# %% [markdown]
# # 3. Correlation

# %%
# %%bash
# cd /hydra/atac_sexual_final
# echo "#!/bin/bash" > samplecorrelation_april21.sh
# echo "multiBigwigSummary bins -b ./x1/x1wcscoverage_april2021.bw ./x1/x1lysiscoverage_april2021.bw ./x2/x2wcscoverage_april2021.bw ./x2/x2lysiscoverage_april2021.bw ./xins/xins2scoverage_april2021.bw ./xins/xins1overage_april2021.bw ./mansi_atac/SRR8441376_april2021.bw ./mansi_atac/SRR8441377_april2021.bw ./mansi_atac/SRR8441378_april2021.bw ./mansi_atac/SRR8441379_april2021.bw -out samplecorrelation_april21.npz --outRawCounts samplecorrelation_april21.tab" >> samplecorrelation_april21.sh
# chmod +x samplecorrelation_april21.sh
# less samplecorrelation_april21.sh
# Out:
# #!/bin/bash
# multiBigwigSummary bins -b ./x1/x1wcscoverage_april2021.bw ./x1/x1lysiscoverage_april2021.bw ./x2/x2wcscoverage_april2021.bw ./x2/x2lysiscoverage_april2021.bw ./xins/xins2scoverage_april2021.bw ./xins/xins1overage_april2021.bw ./mansi_atac/SRR8441376_april2021.bw ./mansi_atac/SRR8441377_april2021.bw ./mansi_atac/SRR8441378_april2021.bw ./mansi_atac/SRR8441379_april2021.bw -out samplecorrelation_april21.npz --outRawCounts samplecorrelation_april21.tab

# %%
#%%bash
#cd /hydra/atac_sexual_final
#nohup ./samplecorrelation_april21.sh > nohup_cov.out 2>&1  </dev/null &

# %%
# %%bash
# cd /hydra/atac_sexual_final
# plotCorrelation -in samplecorrelation_april21.npz --corMethod spearman --skipZeros --whatToPlot scatterplot -o samplecorrelation_april21.png
